# %%
import pandas as pd

# %%
df = pd.read_csv('corrected_assignment.csv', delimiter='\t')

# %%
print(df)
# Out:
#    ,IMBD title ID,Original titlÊ,Release year,Genrë¨,Duration,Country,Content Rating,Director,Unnamed: 8,Income, Votes ,Score
# 0   0,tt0111161,The Shawshank Redemption,02/10/199...
# 1   1,tt0068646,The Godfather,09 21 1972,"Crime, D...
# 2   2,tt0468569,The Dark Knight, 23 -07-2008,"Acti...
# 3   3,tt0071562,The Godfather: Part II,09/25/1975,...
# 4   4,tt0110912,Pulp Fiction,10/28/1994,"Crime, Dr...
# ..                                                ...
# 95  96,tt0070735,The Sting,03/21/1974,"Comedy, Cri...
# 96  97,tt0082096,Das Boot,03/18/1982,"Adventure, D...
# 97  98,tt0059578,Per qualche dollaro in piÃ¹,12/20...
# 98  99,tt1832382,Jodaeiye Nader az Simin,10/21/201...
# 99  100,tt0045152,Singin' in the Rain,02/05/1953,"...
#
# [100 rows x 1 columns]

# %%
df = pd.read_csv('corrected_assignment.csv')

# %%
df
# Out:
#     Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0            0     tt0111161     The Shawshank Redemption    02/10/1995
# 1            1     tt0068646                The Godfather    09 21 1972
# 2            2     tt0468569              The Dark Knight   23 -07-2008
# 3            3     tt0071562       The Godfather: Part II    09/25/1975
# 4            4     tt0110912                 Pulp Fiction    10/28/1994
# ..         ...           ...                          ...           ...
# 95          96     tt0070735                    The Sting    03/21/1974
# 96          97     tt0082096                     Das Boot    03/18/1982
# 97          98     tt0059578  Per qualche dollaro in piÃ¹    12/20/1965
# 98          99     tt1832382      Jodaeiye Nader az Simin    10/21/2011
# 99         100     tt0045152          Singin' in the Rain    02/05/1953
#
#                         Genrë¨ Duration       Country Content Rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      100 non-null    int64
#  1   IMBD title ID   100 non-null    object
#  2   Original titlÊ  100 non-null    object
#  3   Release year    100 non-null    object
#  4   Genrë¨          100 non-null    object
#  5   Duration        99 non-null     object
#  6   Country         100 non-null    object
#  7   Content Rating  77 non-null     object
#  8   Director        100 non-null    object
#  9   Unnamed: 8      0 non-null      float64
#  10  Income          100 non-null    object
#  11   Votes          100 non-null    object
#  12  Score           100 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  Unnamed: 8
# count  100.000000         0.0
# mean    50.370000         NaN
# std     29.209676         NaN
# min      0.000000         NaN
# 25%     25.750000         NaN
# 50%     50.500000         NaN
# 75%     75.250000         NaN
# max    100.000000         NaN

# %%
df.pop('Unnamed: 0')
# Out:
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
#      ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
# Name: Unnamed: 0, Length: 100, dtype: int64

# %%
df.pop('Unnamed: 8')
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 95   NaN
# 96   NaN
# 97   NaN
# 98   NaN
# 99   NaN
# Name: Unnamed: 8, Length: 100, dtype: float64

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#    imbd title id               original titlê  release year  \
# 0      tt0111161     The Shawshank Redemption    02/10/1995
# 1      tt0068646                The Godfather    09 21 1972
# 2      tt0468569              The Dark Knight   23 -07-2008
# 3      tt0071562       The Godfather: Part II    09/25/1975
# 4      tt0110912                 Pulp Fiction    10/28/1994
# ..           ...                          ...           ...
# 95     tt0070735                    The Sting    03/21/1974
# 96     tt0082096                     Das Boot    03/18/1982
# 97     tt0059578  Per qualche dollaro in piÃ¹    12/20/1965
# 98     tt1832382      Jodaeiye Nader az Simin    10/21/2011
# 99     tt0045152          Singin' in the Rain    02/05/1953
#
#                         genrë¨ duration       country content rating  \
# 0                        Drama      142           USA              R
# 1                 Crime, Drama      175           USA              R
# ...

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#    imbd title id               original titlê  release year  \
# 0      tt0111161     The Shawshank Redemption    02/10/1995
# 1      tt0068646                The Godfather    09 21 1972
# 2      tt0468569              The Dark Knight   23 -07-2008
# 3      tt0071562       The Godfather: Part II    09/25/1975
# 4      tt0110912                 Pulp Fiction    10/28/1994
# ..           ...                          ...           ...
# 95     tt0070735                    The Sting    03/21/1974
# 96     tt0082096                     Das Boot    03/18/1982
# 97     tt0059578  Per qualche dollaro in piÃ¹    12/20/1965
# 98     tt1832382      Jodaeiye Nader az Simin    10/21/2011
# 99     tt0045152          Singin' in the Rain    02/05/1953
#
#                         genrë¨ duration       country content rating  \
# 0                        Drama      142           USA              R
# 1                 Crime, Drama      175           USA              R
# ...

# %%
new_column_names = {
    'imbd title id': 'imdb_id',
    'original titlê': 'original_title',
    'release year': 'release_year',
    'genrë¨': 'genre',
    'content rating': 'rating',}

# %%
df.rename(columns=new_column_names, inplace=True)

# %%
df
# Out:
#       imdb_id               original_title  release_year  \
# 0   tt0111161     The Shawshank Redemption    02/10/1995
# 1   tt0068646                The Godfather    09 21 1972
# 2   tt0468569              The Dark Knight   23 -07-2008
# 3   tt0071562       The Godfather: Part II    09/25/1975
# 4   tt0110912                 Pulp Fiction    10/28/1994
# ..        ...                          ...           ...
# 95  tt0070735                    The Sting    03/21/1974
# 96  tt0082096                     Das Boot    03/18/1982
# 97  tt0059578  Per qualche dollaro in piÃ¹    12/20/1965
# 98  tt1832382      Jodaeiye Nader az Simin    10/21/2011
# 99  tt0045152          Singin' in the Rain    02/05/1953
#
#                          genre duration       country rating  \
# 0                        Drama      142           USA      R
# 1                 Crime, Drama      175           USA      R
# 2         Action, Crime, Drama      152            US  PG-13
# ...

# %%
df['new_genre']=df['genre'].str.split(',', expand=True)[0]

# %%
df
# Out:
#       imdb_id               original_title  release_year  \
# 0   tt0111161     The Shawshank Redemption    02/10/1995
# 1   tt0068646                The Godfather    09 21 1972
# 2   tt0468569              The Dark Knight   23 -07-2008
# 3   tt0071562       The Godfather: Part II    09/25/1975
# 4   tt0110912                 Pulp Fiction    10/28/1994
# ..        ...                          ...           ...
# 95  tt0070735                    The Sting    03/21/1974
# 96  tt0082096                     Das Boot    03/18/1982
# 97  tt0059578  Per qualche dollaro in piÃ¹    12/20/1965
# 98  tt1832382      Jodaeiye Nader az Simin    10/21/2011
# 99  tt0045152          Singin' in the Rain    02/05/1953
#
#                          genre duration       country rating  \
# 0                        Drama      142           USA      R
# 1                 Crime, Drama      175           USA      R
# 2         Action, Crime, Drama      152            US  PG-13
# ...

# %%
df.pop('genre')
# Out:
# 0                          Drama
# 1                   Crime, Drama
# 2           Action, Crime, Drama
# 3                   Crime, Drama
# 4                   Crime, Drama
#                  ...
# 95          Comedy, Crime, Drama
# 96    Adventure, Drama, Thriller
# 97                       Western
# 98                         Drama
# 99      Comedy, Musical, Romance
# Name: genre, Length: 100, dtype: object

# %%
df
# Out:
#       imdb_id               original_title  release_year duration  \
# 0   tt0111161     The Shawshank Redemption    02/10/1995      142
# 1   tt0068646                The Godfather    09 21 1972      175
# 2   tt0468569              The Dark Knight   23 -07-2008      152
# 3   tt0071562       The Godfather: Part II    09/25/1975      220
# 4   tt0110912                 Pulp Fiction    10/28/1994
# ..        ...                          ...           ...      ...
# 95  tt0070735                    The Sting    03/21/1974      129
# 96  tt0082096                     Das Boot    03/18/1982      149
# 97  tt0059578  Per qualche dollaro in piÃ¹    12/20/1965      132
# 98  tt1832382      Jodaeiye Nader az Simin    10/21/2011      123
# 99  tt0045152          Singin' in the Rain    02/05/1953      103
#
#          country rating              director         income     votes  score  \
# 0            USA      R        Frank Darabont     $ 28815245  2.278.845   9.3
# ...

# %%
df.rename(columns={'new_genre': 'genre'}, inplace=True)

# %%
df
# Out:
#       imdb_id               original_title  release_year duration  \
# 0   tt0111161     The Shawshank Redemption    02/10/1995      142
# 1   tt0068646                The Godfather    09 21 1972      175
# 2   tt0468569              The Dark Knight   23 -07-2008      152
# 3   tt0071562       The Godfather: Part II    09/25/1975      220
# 4   tt0110912                 Pulp Fiction    10/28/1994
# ..        ...                          ...           ...      ...
# 95  tt0070735                    The Sting    03/21/1974      129
# 96  tt0082096                     Das Boot    03/18/1982      149
# 97  tt0059578  Per qualche dollaro in piÃ¹    12/20/1965      132
# 98  tt1832382      Jodaeiye Nader az Simin    10/21/2011      123
# 99  tt0045152          Singin' in the Rain    02/05/1953      103
#
#          country rating              director         income     votes  score  \
# 0            USA      R        Frank Darabont     $ 28815245  2.278.845   9.3
# ...

# %%
df['release_year'] = pd.to_datetime(df['release_year'], errors='coerce')
# Out:
# C:\Users\Olubunmi A. Asaaju\AppData\Local\Temp\ipykernel_19348\2580657854.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['release_year'] = pd.to_datetime(df['release_year'], errors='coerce')

# %%
df['release_year_formatted'] = df['release_year'].dt.strftime('%d/%m/%y')

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#          country rating              director         income     votes  score  \
# 0            USA      R        Frank Darabont     $ 28815245  2.278.845   9.3
# ...

# %%
import seaborn as sb

# %%
sb.countplot(data=df, y='country')
# Out:
# <Axes: xlabel='count', ylabel='country'>

# %%
country_mapping = {
    'USA': 'United States',
    'US': 'United States',
    'US.': 'United States',
    'New Zesland':'New Zealand',
    'New Zeland':'New Zealand',
    'Italy1':'Italy', 'West Germany': 'Germany'}

# %%
df['country'] = df['country'].replace(country_mapping)

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director         income     votes   \
# 0   United States      R        Frank Darabont     $ 28815245  2.278.845
# ...

# %%
df.loc[3, 'income'] = '$ 408,035,783'

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director         income     votes   \
# 0   United States      R        Frank Darabont     $ 28815245  2.278.845
# ...

# %%
df['income'] = df['income'].str.replace(',', '').str.replace('$', '').astype(int)
# Out:
# C:\Users\Olubunmi A. Asaaju\AppData\Local\Temp\ipykernel_19348\3145537546.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['income'] = df['income'].str.replace(',', '').str.replace('$', '').astype(int)
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df['income'] = df['income'].str.replace(',', '').str.replace('$', '').astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# ...

# %%
df['income'].str.replace(',', '')
# Out:
# 0       $ 28815245
# 1      $ 246120974
# 2     $ 1005455211
# 3      $ 408035783
# 4      $ 222831817
#           ...
# 95     $ 156000000
# 96      $ 11487676
# 97      $ 15000000
# 98      $ 22926076
# 99       $ 1864182
# Name: income, Length: 100, dtype: object

# %%
df['income'].str.replace('$', '')
# Out:
# C:\Users\Olubunmi A. Asaaju\AppData\Local\Temp\ipykernel_19348\2477988630.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['income'].str.replace('$', '')
# 0         28815245
# 1        246120974
# 2       1005455211
# 3      408,035,783
# 4        222831817
#           ...
# 95       156000000
# 96        11487676
# 97        15000000
# 98        22926076
# 99         1864182
# Name: income, Length: 100, dtype: object

# %%
df['income']=df['income'].str.replace('$', '')
# Out:
# C:\Users\Olubunmi A. Asaaju\AppData\Local\Temp\ipykernel_19348\1631466562.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['income']=df['income'].str.replace('$', '')

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director        income     votes  score  \
# 0   United States      R        Frank Darabont      28815245  2.278.845   9.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   imdb_id                 100 non-null    object
#  1   original_title          100 non-null    object
#  2   release_year            97 non-null     datetime64[ns]
#  3   duration                99 non-null     object
#  4   country                 100 non-null    object
#  5   rating                  77 non-null     object
#  6   director                100 non-null    object
#  7   income                  100 non-null    object
#  8    votes                  100 non-null    object
#  9   score                   100 non-null    object
#  10  genre                   100 non-null    object
#  11  release_year_formatted  97 non-null     object
# dtypes: datetime64[ns](1), object(11)
# memory usage: 9.5+ KB

# %%
df.pop('release_year_formatted')
# Out:
# 0     10/02/95
# 1     21/09/72
# 2     23/07/08
# 3     25/09/75
# 4     28/10/94
#         ...
# 95    21/03/74
# 96    18/03/82
# 97    20/12/65
# 98    21/10/11
# 99    05/02/53
# Name: release_year_formatted, Length: 100, dtype: object

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director        income     votes  score  \
# 0   United States      R        Frank Darabont      28815245  2.278.845   9.3
# ...

# %%
df.loc[3, 'income']= '408035783'

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director       income     votes  score  \
# 0   United States      R        Frank Darabont     28815245  2.278.845   9.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   imdb_id         100 non-null    object
#  1   original_title  100 non-null    object
#  2   release_year    97 non-null     datetime64[ns]
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   rating          77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8    votes          100 non-null    object
#  9   score           100 non-null    object
#  10  genre           100 non-null    object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 8.7+ KB

# %%
df['income'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df['income'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df['income']
# Out:
# 0        28815245
# 1       246120974
# 2      1005455211
# 3       408035783
# 4       222831817
#          ...
# 95      156000000
# 96       11487676
# 97       15000000
# 98       22926076
# 99        1864182
# Name: income, Length: 100, dtype: object

# %%
df['income'] = pd.to_numeric(df['income'], errors='coerce')

# %%
print(df.dtypes)
# Out:
# imdb_id                   object
# original_title            object
# release_year      datetime64[ns]
# duration                  object
# country                   object
# rating                    object
# director                  object
# income                     int64
#  votes                    object
# score                     object
# genre                     object
# dtype: object

# %%
print(df['income'].isnull().sum())
# Out:
# 0

# %%
df['duration']
# Out:
# 0     142
# 1     175
# 2     152
# 3     220
# 4
#      ...
# 95    129
# 96    149
# 97    132
# 98    123
# 99    103
# Name: duration, Length: 100, dtype: object

# %%
print(df['duration'].isnull().sum())
# Out:
# 1

# %%
df['income'] = pd.to_numeric(df['income'], errors='coerce')

# %%
print(df.dtypes)
# Out:
# imdb_id                   object
# original_title            object
# release_year      datetime64[ns]
# duration                  object
# country                   object
# rating                    object
# director                  object
# income                     int64
#  votes                    object
# score                     object
# genre                     object
# dtype: object

# %%
df['votes'] = df['votes'].str.replace('.', '')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'votes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# _Looks like there's something wrong with our "votes" column._

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director      income     votes  score  \
# 0   United States      R        Frank Darabont    28815245  2.278.845   9.3
# ...

# %%
df['score'] = df['score'].str.replace(',', '')

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director      income     votes  score  \
# 0   United States      R        Frank Darabont    28815245  2.278.845   9.3
# ...

# %%
print(df.dtypes)
# Out:
# imdb_id                   object
# original_title            object
# release_year      datetime64[ns]
# duration                  object
# country                   object
# rating                    object
# director                  object
# income                     int64
#  votes                    object
# score                     object
# genre                     object
# dtype: object

# %%
df['score']
# Out:
# 0     9.3
# 1     9.2
# 2       9
# 3     9.0
# 4     89f
#      ...
# 95    7.5
# 96    7.5
# 97    7.4
# 98    7.4
# 99    7.4
# Name: score, Length: 100, dtype: object

# %%
df.loc[4, 'score']= '8.9'

# %%
df['score']
# Out:
# 0     9.3
# 1     9.2
# 2       9
# 3     9.0
# 4     8.9
#      ...
# 95    7.5
# 96    7.5
# 97    7.4
# 98    7.4
# 99    7.4
# Name: score, Length: 100, dtype: object

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director      income     votes  score  \
# 0   United States      R        Frank Darabont    28815245  2.278.845   9.3
# ...

# %%
print(df['income'].isnull().sum())
# Out:
# 0

# %%
row_with_double_period = df[df['score'] == '8..8']

# %%
print(row_with_double_period)
# Out:
#      imdb_id original_title release_year duration        country rating  \
# 8  tt1375666      Inception   2010-09-24      148  United States  PG-13
#
#             director     income     votes  score   genre
# 8  Christopher Nolan  869784991  2.002.816  8..8  Action

# %%
df.head(9)
# Out:
#      imdb_id                                 original_title release_year  \
# 0  tt0111161                       The Shawshank Redemption   1995-02-10
# 1  tt0068646                                  The Godfather   1972-09-21
# 2  tt0468569                                The Dark Knight   2008-07-23
# 3  tt0071562                         The Godfather: Part II   1975-09-25
# 4  tt0110912                                   Pulp Fiction   1994-10-28
# 5  tt0167260  The Lord of the Rings: The Return of the King   2004-02-22
# 6  tt0108052                               Schindler's List   1994-03-11
# 7  tt0050083                                   12 Angry Men   1957-09-04
# 8  tt1375666                                      Inception   2010-09-24
#
#   duration        country     rating              director      income  \
# 0      142  United States          R        Frank Darabont    28815245
# 1      175  United States          R  Francis Ford Coppola   246120974
# ...

# %%
df.loc[8, 'score']= '8.8'

# %%
df.head(9)
# Out:
#      imdb_id                                 original_title release_year  \
# 0  tt0111161                       The Shawshank Redemption   1995-02-10
# 1  tt0068646                                  The Godfather   1972-09-21
# 2  tt0468569                                The Dark Knight   2008-07-23
# 3  tt0071562                         The Godfather: Part II   1975-09-25
# 4  tt0110912                                   Pulp Fiction   1994-10-28
# 5  tt0167260  The Lord of the Rings: The Return of the King   2004-02-22
# 6  tt0108052                               Schindler's List   1994-03-11
# 7  tt0050083                                   12 Angry Men   1957-09-04
# 8  tt1375666                                      Inception   2010-09-24
#
#   duration        country     rating              director      income  \
# 0      142  United States          R        Frank Darabont    28815245
# 1      175  United States          R  Francis Ford Coppola   246120974
# ...

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director      income     votes  score  \
# 0   United States      R        Frank Darabont    28815245  2.278.845   9.3
# ...

# %%
df['score']
# Out:
# 0     9.3
# 1     9.2
# 2       9
# 3     9.0
# 4     8.9
#      ...
# 95    7.5
# 96    7.5
# 97    7.4
# 98    7.4
# 99    7.4
# Name: score, Length: 100, dtype: object

# %%
df.head(9:20)
# Out:
#   Cell In[70], line 1
#     df.head(9:20)
#              ^
# SyntaxError: invalid syntax

# %%
rows_range = df[10:25]

# %%
print(rows_range)
# Out:
#       imdb_id                                     original_title release_year  \
# 10  tt0109830                                       Forrest Gump   1994-10-06
# 11  tt0120737  The Lord of the Rings: The Fellowship of the Ring   2002-01-18
# 12  tt0060196                    Il buono, il brutto, il cattivo   1966-12-23
# 13  tt0133093                                         The Matrix   1999-05-07
# 14  tt0167261              The Lord of the Rings: The Two Towers   2003-01-16
# 15  tt0080684     Star Wars: Episode V - The Empire Strikes Back   1980-09-19
# 16  tt0099685                                         Goodfellas   1990-09-20
# 17  tt0073486                    One Flew Over the Cuckoo's Nest   1976-11-18
# 18  tt0816692                                       Interstellar   2014-11-06
# 19  tt0114369                                              Se7en   1995-12-15
# 20  tt0102926                           The Silence of the Lambs   1991-03-05
# ...

# %%
rows_range = df[26:45]

# %%
print(rows_range)
# Out:
#       imdb_id              original_title release_year duration  \
# 26  tt0118799            La vita B9 bella   1997-12-20      116
# 27  tt6751668                Gisaengchung   2019-11-07      132
# 28  tt0038650       It's a Wonderful Life   1948-03-11      130
# 29  tt0047478        Shichinin no samurai   1955-08-19      207
# 30  tt0172495                   Gladiator   2000-05-19      155
# 31  tt0407887                The Departed   2006-10-27      151
# 32  tt0482571                The Prestige   2006-12-22      130
# 33  tt0088763          Back to the Future   1985-10-18      116
# 34  tt0120586          American History X   1999-08-27      119
# 35  tt0110413                       LÃ©on   1995-04-07      110
# 36  tt0103064  Terminator 2: Judgment Day   1991-12-19      137
# 37  tt0114814          The Usual Suspects   1995-11-30      106
# 38  tt0110357               The Lion King   1994-11-25       88
# 39  tt7286456                       Joker   2019-10-03      122
# ...

# %%
df.loc[10, 'score']= '8.8'

# %%
df.loc[14, 'score']= '8.7'

# %%
df.loc[15, 'score']= '8.7'

# %%
df.loc[20, 'score']= '8.6'

# %%
df['score']
# Out:
# 0     9.3
# 1     9.2
# 2       9
# 3     9.0
# 4     8.9
#      ...
# 95    7.5
# 96    7.5
# 97    7.4
# 98    7.4
# 99    7.4
# Name: score, Length: 100, dtype: object

# %%
inconsistent_values = df['score'].value_counts()

# %%
print(inconsistent_values)
# Out:
# 8.6    12
# 8.3     8
# 8.2     8
# 8.4     7
# 8.1     7
# 7.8     6
# 7.5     6
# 8.5     6
# 8       6
# 8.8     5
# 8.7     5
# 7.9     5
# 7.6     4
# 8.9     4
# 7.7     4
# 7.4     3
# 9.2     1
# 9.0     1
# 9       1
# 9.3     1
# Name: score, dtype: int64

# %%
df['score']
# Out:
# 0     9.3
# 1     9.2
# 2       9
# 3     9.0
# 4     8.9
#      ...
# 95    7.5
# 96    7.5
# 97    7.4
# 98    7.4
# 99    7.4
# Name: score, Length: 100, dtype: object

# %%
df['score'] = df['score'].astype(float)

# %%
df['score']
# Out:
# 0     9.3
# 1     9.2
# 2     9.0
# 3     9.0
# 4     8.9
#      ...
# 95    7.5
# 96    7.5
# 97    7.4
# 98    7.4
# 99    7.4
# Name: score, Length: 100, dtype: float64

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director      income     votes   score  \
# 0   United States      R        Frank Darabont    28815245  2.278.845    9.3
# ...

# %% [markdown]
# _For some reason, every attempt to work on the 'votes' column were abortive. I couldn't even drop it. It reads when you open the entire table, but somehow vanishes when attempted on._

# %%
inconsistent_values = df['director'].value_counts()

# %%
print(inconsistent_values)
# Out:
# Christopher Nolan                  6
# Stanley Kubrick                    5
# Alfred Hitchcock                   4
# Quentin Tarantino                  4
# Sergio Leone                       4
#                                   ..
# Isao Takahata                      1
# Giuseppe Tornatore                 1
# Lana Wachowski, Lilly Wachowski    1
# Andrew Stanton                     1
# Stanley Donen                      1
# Name: director, Length: 64, dtype: int64

# %%
df['director']
# Out:
# 0           Frank Darabont
# 1     Francis Ford Coppola
# 2        Christopher Nolan
# 3     Francis Ford Coppola
# 4        Quentin Tarantino
#               ...
# 95         George Roy Hill
# 96       Wolfgang Petersen
# 97            Sergio Leone
# 98          Asghar Farhadi
# 99           Stanley Donen
# Name: director, Length: 100, dtype: object

# %%
df
# Out:
#       imdb_id               original_title release_year duration  \
# 0   tt0111161     The Shawshank Redemption   1995-02-10      142
# 1   tt0068646                The Godfather   1972-09-21      175
# 2   tt0468569              The Dark Knight   2008-07-23      152
# 3   tt0071562       The Godfather: Part II   1975-09-25      220
# 4   tt0110912                 Pulp Fiction   1994-10-28
# ..        ...                          ...          ...      ...
# 95  tt0070735                    The Sting   1974-03-21      129
# 96  tt0082096                     Das Boot   1982-03-18      149
# 97  tt0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 98  tt1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 99  tt0045152          Singin' in the Rain   1953-02-05      103
#
#           country rating              director      income     votes   score  \
# 0   United States      R        Frank Darabont    28815245  2.278.845    9.3
# ...
